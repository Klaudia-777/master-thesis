# %% [markdown]
# <a href="https://colab.research.google.com/github/Klaudia-777/master-thesis/blob/main/train_from_gdrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# %cd /content/gdrive/MyDrive/Praca magisterska/collab
# !pip install -r yolov5/requirements.txt
# %cd yolov5

# %%
# %pip install -q wandb

# %%
import wandb
wandb.init()
wandb.config.update({"allow_val_change": True})

# %%
# !python train.py --img 640 --batch 8 --epochs 200 --data dataset.yaml --save_period 5 --weights yolov5l.pt --name "trenowanie_merged_photos"

# %%
# !python train.py --resume
