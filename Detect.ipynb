# %% [markdown]
# <a href="https://colab.research.google.com/github/Klaudia-777/master-thesis/blob/main/Detect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# %cd /content/gdrive/MyDrive/Praca magisterska/collab
# !pip install -r yolov5/requirements.txt
# %cd yolov5

# %%
# !cp "/content/gdrive/MyDrive/Praca magisterska/models/model1" .
# !cp "/content/gdrive/MyDrive/Praca magisterska/collab/yolov5/runs/train/trenowanie_merged_photos/weights/last.pt" .

# %%
# %ls

# %%
# !cp "/content/gdrive/MyDrive/Praca magisterska/collab/film/grodzka_rynek1.mp4" .

# %%
# !ls

# %%
# !python detect.py --img-size=1920 --source playlist_20210401T080001+0200.mp4 --weights model1 --classes 0 1 2 3 --conf-thres=0.4

# !python detect.py --img-size=1920 --source grodzka_rynek1.mp4 --weights last.pt --classes 0 1 2 3 --conf-thres=0.4
